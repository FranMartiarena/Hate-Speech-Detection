# %%
import pandas as pd

# %%
pd.set_option('display.max_colwidth', None) #para ver todo el output de filas de cols en pandas
pd.set_option('display.width', None)

# %%
# Load local CSV file
df = pd.read_csv('../data_set/hateval2019_es_train.csv')

# View the first 5 rows
print(df.iloc[[9]][["text", "HS"]])
# Out:
#                                         text  HS
# 9  @MaivePerez Llora te lo.mereces por zorra   1
